# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import cv2
import matplotlib.pyplot as plt

# %%
iris = load_iris()

X = iris.data[:, 2:]
y = iris.target

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# Model fit
tree_clf = DecisionTreeClassifier()
tree_clf.fit( X, y )
# Out:
# DecisionTreeClassifier()

# %%
export_graphviz(
    tree_clf,
    out_file='tree.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)

# %%
# !dot -Tpng tree.dot -o tree.png

# %%
img = cv2.imread('tree.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %% [markdown]
# max_depth = tamanho maximo de crescimento da Arvore
#
# min_samples_split = numero minimo de amostras que a folha seguinte deve ter após a divisão
#
# min_samples_leaf = numero minimo de amostras que a folha deve ter para fazer um novo split
#
# max_features = numero maximo de atributos avaliados para divisão de cada nó

# %%
tree_clf = tr.DecisionTreeClassifier(max_depth=2)
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %%
tree_clf = tr.DecisionTreeClassifier(
        max_depth=10,
        min_samples_leaf=30)
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %%
tree_clf = tr.DecisionTreeClassifier(
        max_depth=10,
        min_samples_leaf=20)
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %%
tree_clf = tr.DecisionTreeClassifier(
        max_depth=10,
        min_samples_split=30)
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %%
tree_clf = tr.DecisionTreeClassifier(
        max_depth=10,
        max_features=1)
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %%
tree_clf = tr.DecisionTreeClassifier(
        max_depth=10,
        max_features=2)
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %%
tree_clf = tr.DecisionTreeClassifier(
        max_depth=10,
        max_features='sqrt')
tree_clf.fit( X, y )
tr.export_graphviz(
    tree_clf,
    out_file='tree2.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
# !dot -Tpng tree2.dot -o tree2.png
img = cv2.imread('tree2.png')
plt.figure( figsize= (20,20) )
plt.imshow(img)

# %% [markdown]
# ### Metricas de Avaliação
